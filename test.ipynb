# %%
module_path = {
    "test_module": r"C:\pioda_stuff\projects\python\git_log_to_excel"
}
start_date: str = "2025-01-01"
end_date: str = "2025-02-28"
output_path = "test.xlsx"

from git_log_to_excel import log_collector
log_collector(module_path=module_path, start_date="2025-01-01", end_date="2025-01-01", output_path=output_path)
# Out:
# 写入成功!
